# %% [markdown]
# ## Here I am storing a lot of short but important information about algo-trading HOW TO USE file

# %% [markdown]
# ### How to import and download data

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
APPLE = yf.download("AAPL", start = "2010-01-01" , end = "2021-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
APPLE
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.478999
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.490200
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.386966
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.375158
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.417541
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.679749
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.317825
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.529404
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.399368
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.387222
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %% [markdown]
# If i want to read documentation fast i can select func and  press shift+tab

# %%
ticker = ['SPY', 'KO', 'AAPL']

# %%
stocks = yf.download(ticker, start = "2010-01-01" , end = "2021-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks.head #5 first
# Out:
# <bound method NDFrame.head of              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478999  18.498022   87.129936    7.643214  28.520000
# 2010-01-05    6.490200  18.274250   87.360573    7.656429  28.174999
# 2010-01-06    6.386966  18.267769   87.422089    7.534643  28.165001
# 2010-01-07    6.375158  18.222364   87.791107    7.520714  28.094999
# 2010-01-08    6.417541  17.885092   88.083298    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679749  48.779106  352.967987  131.970001  53.439999
# 2020-12-28  134.317825  49.436314  356.000305  136.690002  54.160000
# 2020-12-29  132.529404  49.408932  355.321136  134.869995  54.130001
# 2020-12-30  131.399368  49.691887  355.828125  133.720001  54.439999
# 2020-12-31  130.387222  50.057011  357.635986  132.690002  54.840000
#
# ...

# %%
stocks.tail #5 last
# Out:
# <bound method NDFrame.tail of              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478999  18.498022   87.129936    7.643214  28.520000
# 2010-01-05    6.490200  18.274250   87.360573    7.656429  28.174999
# 2010-01-06    6.386966  18.267769   87.422089    7.534643  28.165001
# 2010-01-07    6.375158  18.222364   87.791107    7.520714  28.094999
# 2010-01-08    6.417541  17.885092   88.083298    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679749  48.779106  352.967987  131.970001  53.439999
# 2020-12-28  134.317825  49.436314  356.000305  136.690002  54.160000
# 2020-12-29  132.529404  49.408932  355.321136  134.869995  54.130001
# 2020-12-30  131.399368  49.691887  355.828125  133.720001  54.439999
# 2020-12-31  130.387222  50.057011  357.635986  132.690002  54.840000
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %% [markdown]
# ### How to convert to csv and work with this csv

# %%
stocks.to_csv('data.csv')

# %%
stocks = pd.read_csv('data.csv')

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.478999137878418  18.498022079467773   87.12993621826172
# 3     2010-01-05   6.490199565887451  18.274250030517578    87.3605728149414
# 4     2010-01-06   6.386966228485107   18.26776885986328   87.42208862304688
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478999  18.498022   87.129936    7.643214  28.520000
# 2010-01-05    6.490200  18.274250   87.360573    7.656429  28.174999
# 2010-01-06    6.386966  18.267769   87.422089    7.534643  28.165001
# 2010-01-07    6.375158  18.222364   87.791107    7.520714  28.094999
# 2010-01-08    6.417541  17.885092   88.083298    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679749  48.779106  352.967987  131.970001  53.439999
# 2020-12-28  134.317825  49.436314  356.000305  136.690002  54.160000
# 2020-12-29  132.529404  49.408932  355.321136  134.869995  54.130001
# 2020-12-30  131.399368  49.691887  355.828125  133.720001  54.439999
# 2020-12-31  130.387222  50.057011  357.635986  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %% [markdown]
# ### Describe and loc

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.562566    32.208758   182.052367    33.777537    41.320121
# std      24.614793     8.183724    69.703575    24.572747     6.808527
# min       5.814177    16.373821    79.271935     6.858929    25.014999
# 25%      15.201318    26.605553   114.881241    17.484285    37.660000
# 50%      24.549242    31.768923   175.981079    26.987499    41.759998
# 75%      40.931637    37.628510   241.932800    43.007500    45.549999
# max     134.317825    53.069557   357.635986   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
stocks.loc[:,"Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
adj_close = stocks.loc[:,'Adj Close'].copy()

# %%
adj_close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    6.478999  18.498022   87.129936
# 2010-01-05    6.490200  18.274250   87.360573
# 2010-01-06    6.386966  18.267769   87.422089
# 2010-01-07    6.375158  18.222364   87.791107
# 2010-01-08    6.417541  17.885092   88.083298
# ...                ...        ...         ...
# 2020-12-24  129.679749  48.779106  352.967987
# 2020-12-28  134.317825  49.436314  356.000305
# 2020-12-29  132.529404  49.408932  355.321136
# 2020-12-30  131.399368  49.691887  355.828125
# 2020-12-31  130.387222  50.057011  357.635986
#
# [2769 rows x 3 columns]

# %% [markdown]
# ### Graph

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-pastel')

# %%
close.plot(title = 'My chart')
plt.legend() # отображает все titles в коде

# %%
close. iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %% [markdown]
# #### I need it for comparing different data (It can be usefull for correlation)

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt. legend(fontsize=12)
plt. show()

# %% [markdown]
# ### work with data (shift,

# %%
appl= close.AAPL.copy().to_frame()

# %%
appl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]
